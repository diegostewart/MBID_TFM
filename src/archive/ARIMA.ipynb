# %%
import functions as f 

import pandas as pd
import numpy as np

from sklearn import metrics
from math import sqrt

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline


import warnings
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA

warnings.filterwarnings("ignore")

# %%
# Read dataset
file_path = 'BTCEUR.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0      timestamp     open     high      low    close    volume  \
# 0           0  1578038400000  6244.33  6244.33  6244.33  6244.33  0.002000
# 1           1  1578038460000  6437.82  6437.82  6433.99  6433.99  0.064656
# 2           2  1578038520000  6433.99  6433.99  6433.99  6433.99  0.000000
# 3           3  1578038580000  6478.91  6478.91  6478.91  6478.91  0.064122
# 4           4  1578038640000  6478.91  6478.91  6478.91  6478.91  0.000000
#
#       close_time  quote_asset_volume  number_of_trades  \
# 0  1578038459999           12.488660                 1
# 1  1578038519999          416.067862                 2
# 2  1578038579999            0.000000                 0
# 3  1578038639999          415.440667                 1
# 4  1578038699999            0.000000                 0
#
#    taker_buy_base_asset_volume  taker_buy_quote_asset_volume  unused_field
# 0                     0.002000                     12.488660             0
# 1                     0.000000                      0.000000             0
# 2                     0.000000                      0.000000             0
# 3                     0.064122                    415.440667             0
# 4                     0.000000                      0.000000             0

# %%
#Transform and prepare dataset 
df.drop('Unnamed: 0', axis=1, inplace=True)
df['date'] = df['timestamp'].apply(lambda x:f.unix_to_date(x))
df['time'] = df['timestamp'].apply(lambda x:f.unix_to_time(x))
df['datetime'] = df['timestamp'].apply(lambda x:f.unix_to_datetime(x))
df.set_index("datetime", inplace = True)

# %%
# Filter the DataFrame to include only rows where the time is 12:00:00
df_plot = df[df['time'] == "12:00:00"]
x = df_plot.index
y = df_plot["open"]

fig = plt.figure(figsize = (10, 10))
ax1 = fig.subplots(1, 1)

ax1.plot(x, y, label = "Serie Original")
# ax1.plot(x, y_media, label = "Media de la Serie Original")
ax1.set_ylim(0, np.max(y)*1.3)
ax1.legend(loc = "upper left")
fig.suptitle("BTC/EUR");

# %%
# Filter the DataFrame to include only rows where the time is 12:00:00
df_filtered = df[df['time'] == "12:00:00"]['open']

#Train test split
to_row = int(len(df_filtered)*0.9)
print(to_row)

train_data = df_filtered[0:to_row]
test_data = df_filtered[to_row:]
# Out:
# 1314

# %%
# Plotting train and test data
plt.grid(True)
plt.xlabel('datetime')
plt.ylabel('Open Price')
plt.plot(train_data,'green',label='Train data')
plt.plot(test_data,'blue',label='Test data')
plt.legend()

# %%
type(train_data)
# Out:
# list

# %%
model_predictions = []
n_tester_obser = len(test_data)

train_data = train_data.tolist()
test_data = test_data.tolist()

# %%
len(train_data)
# Out:
# 1460

# %%
for i in range(n_tester_obser):
    model = ARIMA(train_data, order = (4,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    model_predictions.append(output)
    actual_test_value = test_data[i]
    train_data.append(actual_test_value)

print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1459
# Model:                 ARIMA(4, 1, 0)   Log Likelihood              -12166.239
# Date:                Wed, 14 Feb 2024   AIC                          24342.478
# Time:                        14:28:24   BIC                          24368.902
# Sample:                             0   HQIC                         24352.336
#                                - 1459
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0685      0.019     -3.674      0.000      -0.105      -0.032
# ar.L2          0.0246      0.020      1.214      0.225      -0.015       0.064
# ar.L3         -0.0316      0.016     -1.938      0.053      -0.064       0.000
# ar.L4          0.0436      0.018      2.365      0.018       0.007       0.080
# sigma2      1.039e+06   1.58e+04     65.897      0.000    1.01e+06    1.07e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              6756.77
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                            -0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Plotting train and test data

plt.figure(figsize=(15,9))
plt.grid(True)

date_range = df_filtered[to_row:].index

plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BTC Price Prediction')

plt.plot(date_range, model_predictions, color = 'blue', marker = 'o', linestyle = 'dashed',label='BTC predicted price')
plt.plot(date_range, test_data, color = 'red', label='BTC actual price')

plt.legend()
plt.show()
